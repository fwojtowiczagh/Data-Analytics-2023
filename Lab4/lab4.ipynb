# %% [markdown]
# # Lab 4 - Linear models
#
# We focus on models in the form
#
# $$ y \sim \mathrm{Normal}(\alpha+X\beta,\sigma) $$

# %%
from cmdstanpy import CmdStanModel


import arviz as az
import numpy as np
import scipy.stats as stats

import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Excercise 1 - modelling height of !Kung people

# %% [markdown]
# ### Normal model - no predictors
# We will try to fit $\mathrm{Normal}(\mu,\sigma)$ distribution to height data. Special case of linear model with $\beta=0$.

# %%
_BASE_URL = "https://raw.githubusercontent.com/rmcelreath/rethinking/Experimental/data"
HOWELL_DATASET_PATH = f"{_BASE_URL}/Howell1.csv"
d = pd.read_csv(HOWELL_DATASET_PATH, sep=';', header=0)
d=d[d.age>=18] #just adults 
d.head()
# Out:
#     height     weight   age  male
# 0  151.765  47.825606  63.0     1
# 1  139.700  36.485807  63.0     0
# 2  136.525  31.864838  65.0     0
# 3  156.845  53.041914  41.0     1
# 4  145.415  41.276872  51.0     0

# %% [markdown]
# ## Task 1. Prior predictive checks

# %%
model_ppc=CmdStanModel(stan_file='height_1_ppc.stan')

R = 1000
sim=model_ppc.sample(iter_sampling=R,
                     iter_warmup=0,
                     chains=1,
                     fixed_param=True,
                     seed=29042020,refresh=R)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
df_height = sim.draws_pd()
df_height.head()
# Out:
#    lp__  accept_stat__       mu     sigma   height
# 0   0.0            0.0  202.082   8.12614  187.886
# 1   0.0            0.0  180.320  70.33170  289.445
# 2   0.0            0.0  171.378  11.77890  179.104
# 3   0.0            0.0  177.301  19.51800  212.670
# 4   0.0            0.0  162.197   4.67849  169.565

# %%
mu = df_height['mu']
mu.hist(bins='auto', density=True)
plt.title('mu histogram')
plt.show()

# %%
sigma = df_height['sigma']
sigma.hist(bins='auto', density=True)
plt.title('sigma histogram')
plt.show()

# %%
height = df_height['height']
height.hist(bins='auto', density=True)
plt.title('height histogram')
plt.show()

# %%
# joint distribution of mu and sigma

df_height.plot(kind='scatter', x='mu', y='sigma', alpha=0.5)
plt.xlabel('mu')
plt.ylabel('sigma')
plt.title('Joint Distribution')
plt.show()

# %% [markdown]
# 1. Plot histograms of mu, sigma and simulated height.
# 2. Plot a joint distribution of mu and sigma.
# 3. Check if samples are consistent with priors.
# 4. Correct prior parameters to make them reasonably spreaded out.
# 5. Check if observed data is possible to obtain using priors.

# %% [markdown]
# ## Task 2. Model fit and evaluation

# %%
model_1_fit=CmdStanModel(stan_file='height_1_fit.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
fit=model_1_fit.sample(data=dict(N=len(d),
                                   heights=d.height.values),
                         seed=28052020)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█████     | 00:00 Iteration:  900 / 2000 [ 45%]  (Warmup)
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
df_height_fit = fit.draws_pd()
df_height_fit.head()
# Out:
#       lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  divergent__  \
# 0 -898.018       0.872972    0.984543          2.0           3.0          0.0
# 1 -896.649       0.974969    0.984543          2.0           3.0          0.0
# 2 -897.151       0.923820    0.984543          2.0           3.0          0.0
# 3 -897.302       0.978123    0.984543          3.0           7.0          0.0
# 4 -897.409       0.951680    0.984543          2.0           3.0          0.0
#
#    energy__       mu    sigma   height
# 0   898.181  155.334  7.89231  162.442
# 1   898.242  154.856  7.78642  156.138
# 2   897.444  154.986  7.97571  148.449
# 3   897.804  154.118  7.67351  162.232
# 4   898.331  154.303  8.07379  141.051

# %%
# joint distribution of fitted mu and sigma

df_height_fit.plot(kind='scatter', x='mu', y='sigma', alpha=0.5)
plt.xlabel('mu')
plt.ylabel('sigma')
plt.title('Joint Distribution')
plt.show()

# %%
height_fit = df_height_fit['height']
height_fit.hist(bins='auto', density=True)
plt.title('fitted height histogram')
plt.show()

# %%
d.hist(layout=(2, 2), bins='auto', figsize=(20, 9))
plt.show()

# %% [markdown]
# 1. Plot a joint distribution of fitted mu and sigma.
# 2. Plot histograms of data and simulated heights and evaluate the quality of model.

# %% [markdown]
# ## Task 3. Adding predictor to the model - weight
#
# Create column ```c_weight``` in the dataframe containing weights substrated by their mean.

# %%
weight_mean = d["weight"].mean()
d["c_weight"] = d["weight"] - weight_mean

data_sim={'N':50, 'weight':np.linspace(d.c_weight.min(),d.c_weight.max())}

# %% [markdown]
# ## Task 4. Prior predictive checks

# %%
model_ppc=CmdStanModel(stan_file='height_2a_ppc.stan')
R = 1000
sim=model_ppc.sample(data=data_sim, 
                     iter_sampling=R, 
                     iter_warmup=0, 
                     chains=1, 
                     refresh=R,
                     fixed_param=True,
                     seed=29042020)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
df_prior_2a = sim.draws_pd()
df_prior_2a.head()
# Out:
#    lp__  accept_stat__    alpha      beta      sigma  height[1]  height[2]  \
# 0   0.0            0.0  202.082  0.777181  23.208300    194.225    159.524
# 1   0.0            0.0  163.011 -0.006780   0.086958    163.211    163.167
# 2   0.0            0.0  170.730 -1.138640  20.358900    215.418    182.006
# 3   0.0            0.0  165.179 -0.254452   6.415610    177.247    164.322
# 4   0.0            0.0  165.066  1.671020   9.955320    115.820    137.007
#
#    height[3]  height[4]  height[5]  ...  height[41]  height[42]  height[43]  \
# 0    197.989    220.603    245.864  ...     238.502     255.720     248.256
# 1    163.161    163.194    163.193  ...     163.161     162.922     162.841
# 2    181.832    196.674    191.632  ...     192.511     129.182     186.234
# 3    166.991    162.107    166.642  ...     165.673     162.918     164.272
# 4    136.179    137.368    159.047  ...     201.001     199.489     180.252
#
# ...

# %%
min_value = df_prior_2a.loc[:, "height[1]":].min().min()
max_value = df_prior_2a.loc[:, "height[1]":].max().max()

print(f"min value: {min_value}, max value: {max_value}")
# Out:
# min value: -165.28, max value: 468.639

# %%
x = np.linspace(d.weight.min(), d.weight.max(), 1000).reshape((-1, 1000))

alpha = df_prior_2a.loc[:, "alpha"].values.reshape((-1, 1000))
beta = df_prior_2a.loc[:, "beta"].values.reshape((-1, 1000))

y_lines = y_lines = alpha.T + beta.T@x

fig, ax = plt.subplots(figsize = (20, 9))

ax.plot(x[0], y_lines.T, color='r', alpha=0.2)
ax.set_title(r"y = $\alpha + x\beta$")
ax.set_xlabel('Weight')
ax.set_ylabel('Height')
ax.set_ylim([0, 280])

plt.show()

# %% [markdown]
# Plot lines for each sampled slope beta and intercept alpha, verify if possible predicted heights are consistent with minimum (0) and maximum (check Wikipedia) heights observed in nature.

# %% [markdown]
# ## Task 5. Modifying prior
#
# If prior for beta admits negative values, then it makes no sense. Lets change prior to lognormal distribution.

# %%
model_ppc=CmdStanModel(stan_file='height_2b_ppc.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
sim=model_ppc.sample(data=data_sim, 
                     iter_sampling=R, 
                     iter_warmup=0, 
                     chains=1, 
                     refresh=R,
                     fixed_param=True,
                     seed=29042020)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %% [markdown]
# 1. Plot lines for each sampled slope beta and intercept alpha, verify if possible predicted heights are consistent with minimum (0) and maximum (check Wikipedia) heights observed in nature.
# 2. For each simulated weight plot maximum, minimum, and 5, 25, 50, 75, 95 quantiles of simulated weight (all in the same plot). Compare with observed data. Is observed data possible within the prior model?

# %%
df_prior_2b = sim.draws_pd()
df_prior_2b.head()
# Out:
#    lp__  accept_stat__    alpha      beta      sigma  height[1]  height[2]  \
# 0   0.0            0.0  202.082  2.175330  23.208300   174.7640   140.9730
# 1   0.0            0.0  163.011  0.993243   0.086958   149.2910   149.8980
# 2   0.0            0.0  170.730  0.320255  20.358900   195.1110   162.6490
# 3   0.0            0.0  165.179  0.775342   6.415610   162.9130   150.6580
# 4   0.0            0.0  165.066  5.317560   9.955320    65.0619    88.6245
#
#    height[3]  height[4]  height[5]  ...  height[41]  height[42]  height[43]  \
# 0   180.3500   203.8740    230.046  ...     255.474     273.603     267.050
# 1   150.5440   151.2290    151.879  ...     175.300     175.713     176.284
# 2   163.4260   179.2180    175.127  ...     210.221     147.842     205.845
# 3   153.9990   149.7850    154.991  ...     178.174     176.089     178.114
# 4    90.1725    93.7372    117.792  ...     245.266     246.130     229.268
#
# ...

# %%
min_value = df_prior_2b.loc[:, "height[1]":].min().min()
max_value = df_prior_2b.loc[:, "height[1]":].max().max()

print(f"min value: {min_value}, max value: {max_value}")
# Out:
# min value: -202.193, max value: 652.544

# %%
x = np.linspace(d.weight.min(), d.weight.max(), 1000).reshape((-1, 1000))

alpha = df_prior_2b.loc[:, "alpha"].values.reshape((-1, 1000))
beta = df_prior_2b.loc[:, "beta"].values.reshape((-1, 1000))

y_lines = alpha.T + beta.T@x

fig, ax = plt.subplots(figsize = (20, 9))

ax.plot(x[0], y_lines.T, color='r', alpha=0.2)
ax.set_title(r"y = $\alpha + x\beta$")
ax.set_xlabel('Weight')
ax.set_ylabel('Height')
ax.set_ylim([0, 280])

plt.show()

# %%
quantiles = df_prior_2b.quantile([0, 0.05, 0.25, 0.5, 0.75, 0.95, 1])
quantiles
# Out:
#       lp__  accept_stat__      alpha       beta      sigma   height[1]  \
# 0.00   0.0            0.0  146.69600   0.030154   0.003578 -202.193000
# 0.05   0.0            0.0  159.29800   0.191042   0.733272   91.068645
# 0.25   0.0            0.0  168.15775   0.543203   4.240158  139.272750
# 0.50   0.0            0.0  174.90200   0.962892  10.131550  157.164500
# 0.75   0.0            0.0  181.72200   2.049410  20.386800  170.510500
# 0.95   0.0            0.0  192.32570   5.489242  44.697230  194.633150
# 1.00   0.0            0.0  213.98600  26.580300  90.768200  326.518000
#
#       height[2]  height[3]  height[4]  height[5]  ...  height[41]  height[42]  \
# 0.00 -170.51300 -137.17000 -130.58800 -181.84100  ...    16.98400    41.51830
# 0.05   96.33396   98.20991  101.40455  102.33640  ...   156.52860   151.93195
# 0.25  138.39150  141.25825  141.98900  141.37250  ...   176.23475   176.44225
# 0.50  158.27200  159.06600  159.46850  159.18000  ...   189.49050   190.36000
# ...

# %%
q_min = quantiles.iloc[0, 5:]
q_5 = quantiles.iloc[1, 5:]
q_25 = quantiles.iloc[2, 5:]
q_50 = quantiles.iloc[3, 5:]
q_75 = quantiles.iloc[4, 5:]
q_95 = quantiles.iloc[5, 5:]
q_max = quantiles.iloc[6, 5:]

# %%
x = np.linspace(1,50)

fig, ax = plt.subplots(figsize = (20, 9))

ax.plot(x, q_min.values.T, label="Min")
ax.plot(x, q_5.values.T, label="5%")
ax.plot(x, q_25.values.T, label="25%")
ax.plot(x, q_50.values.T, label="50%")
ax.plot(x, q_75.values.T, label="75%")
ax.plot(x, q_95.values.T, label="95%")
ax.plot(x, q_max.values.T, label="Max")

plt.legend()
plt.show()

# %% [markdown]
# ## Task 6. Fitting and evaluating model

# %%
model_2_fit=CmdStanModel(stan_file='height_2_fit.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %% [markdown]
# 1. Create ```data_fit``` dictionary containing data from  ```N``` first rows of dataframe

# %%
N=50
data_fit = {'N': N, 'weight': d.c_weight.iloc[:N].values, 'heights': d.height.iloc[:N].values}

fit=model_2_fit.sample(data=data_fit,seed=28052020)
fit.draws_pd()
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█████████ | 00:00 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
#          lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# 0    -105.565       0.998460    0.722906          2.0           3.0
# 1    -106.153       0.922665    0.722906          3.0           7.0
# 2    -109.728       0.590040    0.722906          2.0           3.0
# 3    -108.535       1.000000    0.722906          2.0           3.0
# 4    -106.664       0.978679    0.722906          3.0           7.0
# ...       ...            ...         ...          ...           ...
# 3995 -106.494       0.995302    0.836319          3.0           7.0
# ...

# %%
Ns = [10, 30, 50, 70, 90, 100]

fig, ax = plt.subplots(2,3, figsize = (20, 9))
ax = ax.T.ravel()

for i in range(len(Ns)):
    N = Ns[i]
    data_fit = {'N': N, 'weight': d.weight.iloc[:N].values, 'heights': d.height.iloc[:N].values}
    fit=model_2_fit.sample(data=data_fit,seed=28052020)
    df = fit.draws_pd()
    alpha = df.loc[:, "alpha"]
    beta = df.loc[:, "beta"]
    ax[i].plot([d.weight.min(),d.weight.max()],[alpha+beta*d.weight.min(), alpha+beta*d.weight.max()], color='r', alpha=0.2)
    ax[i].set_title("N = {}".format(N))
    ax[i].set_xlabel('Weight')
    ax[i].set_ylabel('Height')
    ax[i].set_ylim([130, 180])
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█████████▌| 00:00 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |████████▏ | 00:00 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |███████▋  | 00:00 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
Ns = [10, 30, 50, 70, 90, 100]

fig, ax = plt.subplots(2,3, figsize = (20, 9))
ax = ax.T.ravel()

for i in range(len(Ns)):
    N = Ns[i]
    data_fit = {'N': N, 'weight': d.weight.iloc[:N].values, 'heights': d.height.iloc[:N].values}
    fit=model_2_fit.sample(data=data_fit,seed=28052020)
    df = fit.draws_pd()
    stats = df.describe()
    ax[i].scatter(d.weight.iloc[:N].values, d.height.iloc[:N].values, color='r')
    ax[i].errorbar(d.weight.iloc[:N].values, stats.loc[["mean"]].iloc[:,-N:].to_numpy()[0], yerr=stats.loc[["std"]].iloc[:,-N:].to_numpy()[0], fmt='*')
    ax[i].set_title("N = {}".format(N))
    ax[i].set_xlabel('Weight')
    ax[i].set_ylabel('Height')
    ax[i].set_ylim([130, 180])
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█████████ | 00:00 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |████████▏ | 00:00 Iteration: 1500 / 2000 [ 75%]  (Sampling)
#
#
#
#
#
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█████████▌| 00:00 Iteration: 1800 / 2000 [ 90%]  (Sampling)
#
#
#
#
#
#
#
#
#
#
#
# ...

# %% [markdown]
# 2. Plot lines for each sampled slope beta and intercept alpha. Verify how uncertainity changes with increasing of sample (N)
# 2. For each value of weight plot mean simulated height along with errorbar of one standard deviation (use ```errorbar``` from matplotlib). Compare with observed data (N points). Is observed data possible within the posterior model? What changes when N increases.

# %% [markdown]
# ## Task 7. Extending the model
#
# 1. Center the weight data (substract mean vaule of weight from all values). Test how model works for such data. What is the interpretation of $\alpha$ in such case?
# 2. Using centered data modify your model with a second power of weight, select prior for its coefficient using prior predictive checks and after fitting check if model is still good.
# 3. Try to vectorize the model to avoid necessity of a for loop in the ```model``` block.

# %%
model_ppc=CmdStanModel(stan_file='height_3_ppc.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
data_sim={'N':50, 'weight':np.linspace(d.c_weight.min(),d.c_weight.max())}

R = 1000
sim=model_ppc.sample(data=data_sim, 
                     iter_sampling=R, 
                     iter_warmup=0, 
                     chains=1, 
                     refresh=R,
                     fixed_param=True,
                     seed=29042020)
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.

# %%
df_prior_3 = sim.draws_pd()
df_prior_3.head()
# Out:
#    lp__  accept_stat__    alpha      beta    beta_2     sigma  height[1]  \
# 0   0.0            0.0  202.082  2.175330 -1.272270   1.04927   -76.1583
# 1   0.0            0.0  174.932  0.996298  1.214860  14.64430   407.2770
# 2   0.0            0.0  162.781  4.122610 -0.188217   2.08090    70.1890
# 3   0.0            0.0  188.290  0.516962 -0.217836  18.64680   134.7750
# 4   0.0            0.0  169.086  0.456621 -0.773806  19.99590    29.2870
#
#    height[2]  height[3]  height[4]  ...  height[41]  height[42]  height[43]  \
# 0   -50.4912   -26.6207   -3.71041  ...     42.9892     23.3837     1.71613
# 1   392.8300   373.5070  348.50800  ...    352.8600    384.1240   393.88000
# 2    75.7689    82.6455   82.08360  ...    185.7900    188.7950   184.21000
# 3   160.9520   160.1780  168.54200  ...    154.2670    150.3280   172.52500
# 4    37.6186    67.8447   62.69800  ...     51.5905     37.7140    50.56450
#
# ...

# %%
x = np.linspace(d.weight.min(), d.weight.max(), 1000).reshape((-1, 1000))

alpha = df_prior_3.loc[:, "alpha"].values.reshape((-1, 1000))
beta = df_prior_3.loc[:, "beta"].values.reshape((-1, 1000))
beta_2 = df_prior_3.loc[:, "beta_2"].values.reshape((-1, 1000))

y_lines = alpha.T + beta.T@x + beta_2.T@(x*x)

fig, ax = plt.subplots(figsize = (20, 9))

ax.plot(x[0], y_lines.T, color='r', alpha=0.2)
ax.set_title(r"y = $\alpha + x\beta + x^2\beta$")
ax.set_xlabel('Weight')
ax.set_ylabel('Height')
ax.set_ylim([0, 280])

plt.show()

# %%
model_3_fit=CmdStanModel(stan_file='height_3_fit.stan')
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling

# %%
N=50
data_fit = {'N': N, 'weight': d.c_weight.iloc[:N].values, 'heights': d.height.iloc[:N].values}

fit=model_3_fit.sample(data=data_fit,seed=28052020)
fit.draws_pd()
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█████████ | 00:00 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
#
#
#
#
#
#
# chain 1 |██████████| 00:00 Sampling completed
# chain 2 |██████████| 00:00 Sampling completed
# chain 3 |██████████| 00:00 Sampling completed
# chain 4 |██████████| 00:00 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
#          lp__  accept_stat__  stepsize__  treedepth__  n_leapfrog__  \
# 0    -105.611       0.766789    0.496929          2.0           3.0
# 1    -104.919       0.928782    0.496929          3.0           7.0
# 2    -107.716       0.856990    0.496929          2.0           3.0
# 3    -107.183       0.960615    0.496929          3.0           7.0
# 4    -106.072       0.993015    0.496929          2.0           3.0
# ...       ...            ...         ...          ...           ...
# 3995 -107.232       0.894627    0.505298          2.0           7.0
# ...

# %%
Ns = [10, 30, 50, 70, 90, 100]

fig, ax = plt.subplots(2,3, figsize = (20, 9))
ax = ax.T.ravel()

for i in range(len(Ns)):
    N = Ns[i]
    data_fit = {'N': N, 'weight': d.weight.iloc[:N].values, 'heights': d.height.iloc[:N].values}
    fit=model_3_fit.sample(data=data_fit,seed=28052020)
    df = fit.draws_pd()
    alpha = df.loc[:, "alpha"]
    beta = df.loc[:, "beta"]
    beta_2 = df.loc[:, "beta_2"]
    ax[i].plot([d.weight.min(),d.weight.max()],[alpha+beta*d.weight.min()+beta_2*(d.weight.min()*d.weight.min()), alpha+beta*d.weight.max()+beta_2*(d.weight.max()*d.weight.max())], color='r', alpha=0.2)
    ax[i].set_title("N = {}".format(N))
    ax[i].set_xlabel('Weight')
    ax[i].set_ylabel('Height')
    ax[i].set_ylim([130, 180])
# Out:
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |███████▋  | 00:00 Iteration: 1400 / 2000 [ 70%]  (Sampling)
#
#
#
#
#
#
#
#
#
#
#
# chain 1 |██████████| 00:01 Sampling completed
# chain 2 |██████████| 00:01 Sampling completed
#
# chain 3 |██████████| 00:01 Sampling completed
#
#
# chain 4 |██████████| 00:01 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |█████████ | 00:00 Iteration: 1700 / 2000 [ 85%]  (Sampling)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# chain 1 |██████████| 00:01 Sampling completed
# chain 2 |██████████| 00:01 Sampling completed
# chain 3 |██████████| 00:01 Sampling completed
# chain 4 |██████████| 00:01 Sampling completed
# INFO:cmdstanpy:CmdStan done processing.
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
#
#
# chain 1 |██████████| 00:02 Iteration: 1900 / 2000 [ 95%]  (Sampling)
#
# ...
